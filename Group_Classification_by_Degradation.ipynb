# %% [markdown]
# ## Importing packages

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import os
import numpy as np
import plotly.express as px
import pyarrow.parquet as pq
import plotly.graph_objects as go
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
import duckdb

# %% [markdown]
# #### Functions used

# %%
# Another way of doing it, but it requires much more hardcoding, its here just in case anyone wants to try using it
# def label_degradation_monotonic(df, column='POS_FBK', max_window=800, threshold=1.0, min_stable_cycles=50):
#     """
#     Extracts the upper edge of the signal, forces it to only degrade downwards, 
#     and bridges across unstable intermediate states strictly based on TRUE Cycle count.
#     """
    
#     # --- STEP 1: Extract the Ceiling ---
#     df['Upper_Edge'] = df.groupby('Train_ID')[column].transform(
#         lambda x: x.rolling(window=max_window, min_periods=1, center=True).max()
#     )
    
#     # --- STEP 2: The Monotonic Constraint ---
#     # Annihilates upward spikes and forces a perfectly flat or dropping staircase
#     df['Monotonic_Edge'] = df.groupby('Train_ID')['Upper_Edge'].cummin().round(1)
    
#     # --- STEP 3: Plateau Identifier ---
#     # Group the identical plateau values together
#     df['Plateau_Change'] = df.groupby('Train_ID')['Monotonic_Edge'].diff().fillna(0) != 0
#     df['Plateau_ID'] = df.groupby('Train_ID')['Plateau_Change'].cumsum()
    
#     # --- STEP 4: The Mathematical Cycle Calculation (Vectorized for Speed) ---
#     # Calculate exactly how many actual Cycles elapsed in this plateau
#     cycle_max = df.groupby(['Train_ID', 'Plateau_ID'])['Cycle'].transform('max')
#     cycle_min = df.groupby(['Train_ID', 'Plateau_ID'])['Cycle'].transform('min')
#     df['Plateau_Cycle_Duration'] = cycle_max - cycle_min
    
#     # --- STEP 5: Erase "Steps on the way" ---
#     # Now genuinely checking your min_stable_cycles threshold against true cycles
#     df['Stable_State'] = np.where(df['Plateau_Cycle_Duration'] >= min_stable_cycles, df['Monotonic_Edge'], np.nan)
    
#     # Bridge the gaps
#     df['Prev_Stable'] = df.groupby('Train_ID')['Stable_State'].ffill()
#     df['Next_Stable'] = df.groupby('Train_ID')['Stable_State'].bfill()
    
#     # --- STEP 6: Mark FDI Boundaries ---
#     first_of_new = df.groupby('Train_ID')['Prev_Stable'].diff() < -threshold
#     next_stable_diff = df.groupby('Train_ID')['Next_Stable'].diff() < -threshold
#     last_of_old = next_stable_diff.groupby(df['Train_ID']).shift(-1, fill_value=False)
    
#     df['FDI'] = (first_of_new | last_of_old).astype(int)
    
#     # Clean up intermediate columns, but keep Monotonic_Edge for plotting!
#     cols_to_drop = ['Upper_Edge', 'Plateau_Change', 'Plateau_ID', 'Plateau_Cycle_Duration', 
#                     'Stable_State', 'Prev_Stable', 'Next_Stable']
#     df = df.drop(columns=cols_to_drop)
    
#     return df

def apply_fft_lowpass(signal, cutoff_ratio=0.01):
    """Applies a hard low-pass filter using Fast Fourier Transform."""
    n = len(signal)
    fft_vals = np.fft.rfft(signal)
    frequencies = np.fft.rfftfreq(n)
    
    # Zero out high frequencies
    fft_vals[frequencies > cutoff_ratio] = 0
    return np.fft.irfft(fft_vals, n=n)

def label_degradation_hybrid_fft(df, column='POS_FBK', cutoff_ratio=0.01, window=500, threshold=2.0, min_stable_cycles=3000):
    """
    1. Denoises via FFT.
    2. Applies a rolling window max to ride the upper edge.
    3. Uses plateau identification to mark FDI points.
    """
    
    # --- STEP 1: FFT Denoising ---
    # Convert the thick blue band into a thin line
    df['FFT_Denoised'] = df.groupby('Train_ID')[column].transform(
        lambda x: apply_fft_lowpass(x.values, cutoff_ratio=cutoff_ratio)
    )
    
    # --- STEP 2: Rolling Max ---
    # Glide over the top of the FFT artifacts to create a clean, flat edge
    df['Upper_Edge'] = df.groupby('Train_ID')['FFT_Denoised'].transform(
        lambda x: x.rolling(window=window, min_periods=1, center=True).max()
    )
    
    # Round to snap into perfect identical values for plateau grouping
    df['Monotonic_Edge'] = df.groupby('Train_ID')['Upper_Edge'].cummin().round(1)
    
    # --- STEP 3: Plateau Identifier ---
    # Find identical blocks of values
    df['Plateau_Change'] = df.groupby('Train_ID')['Monotonic_Edge'].diff().fillna(0) != 0
    df['Plateau_ID'] = df.groupby('Train_ID')['Plateau_Change'].cumsum()
    
    # --- STEP 4: The Mathematical Cycle Calculation (Vectorized for Speed) ---
    # Calculate exactly how many actual Cycles elapsed in this plateau
    cycle_max = df.groupby(['Train_ID', 'Plateau_ID'])['Cycle'].transform('max')
    cycle_min = df.groupby(['Train_ID', 'Plateau_ID'])['Cycle'].transform('min')
    df['Plateau_Cycle_Duration'] = cycle_max - cycle_min
    
    # --- STEP 5: Erase "Steps on the way" ---
    # Now genuinely checking your min_stable_cycles threshold against true cycles
    df['Stable_State'] = np.where(df['Plateau_Cycle_Duration'] >= min_stable_cycles, df['Monotonic_Edge'], np.nan)
    
    # Bridge the gaps
    df['Prev_Stable'] = df.groupby('Train_ID')['Stable_State'].ffill()
    df['Next_Stable'] = df.groupby('Train_ID')['Stable_State'].bfill()
    
    # --- STEP 6: Mark FDI Boundaries ---
    first_of_new = df.groupby('Train_ID')['Prev_Stable'].diff() < -threshold
    next_stable_diff = df.groupby('Train_ID')['Next_Stable'].diff() < -threshold
    last_of_old = next_stable_diff.groupby(df['Train_ID']).shift(-1, fill_value=False)
    
    df['FDI'] = (first_of_new | last_of_old).astype(int)

    # -> THE FIX: Mark the absolute last point of EACH train as FDI = 1
    last_indices = df.groupby('Train_ID').tail(0).index
    df.loc[last_indices, 'FDI'] = 1
    
    # Clean up intermediate calculations
    # Keeping 'FFT_Denoised' and 'Upper_Edge' so you can visualize the transformation!
    cols_to_drop = ['Upper_Edge', 'Plateau_Change', 'Plateau_ID', 'Plateau_Cycle_Duration',
                    'Stable_State', 'Prev_Stable', 'Next_Stable']
    df = df.drop(columns=cols_to_drop)
    
    return df

def plot_line_scatter_FDI(df_1, df_2, x_1, x_2, y):
    fig = px.line(
        df_1, 
        x=x_1, 
        y=y, 
        color='Train_ID',
        hover_data=['Train_ID', 'Cycle'],
        title="Door Position with Degradation Events (FDI=1)"
    )

    # 3. Add the FDI=1 points on top of the base plot
    # Note: I highly recommend using 'markers' instead of 'lines' here. 
    # Since FDI=1 happens at isolated moments, drawing a continuous line between them 
    # can make the plot look messy and misrepresent the timeline.
    fig.add_trace(
        go.Scatter(
            x=x_2,
            y=df_2[y],
            mode='markers', # Use 'lines' here if you strictly want a curve
            marker=dict(color='red', size=6, symbol='circle-dot'),
            name='Degradation (FDI=1)',

            # This replicates your hover_data for the Graph Object
            customdata=df_2[['Train_ID', 'Cycle']],
            hovertemplate="Train_ID: %{customdata[0]}<br>Cycle: %{customdata[1]}<br>POS_FBK: %{y}<extra></extra>"
        )
    )

    # 4. Show the combined plot
    fig.show()
    
def cluster_trajectories_gmm(df, n_clusters=3):
    """
    Extracts features from the FDI column and uses GMM to cluster the training runs.
    """
    # 1. Feature Extraction per Train
    feature_list = []
    
    for train_id, group in df.groupby('Train_ID'):
        total_cycles = group['Cycle'].max()
        
        # Calculate degradation metrics using the FDI column
        degradation_events = group[group['FDI'] == 1]
        num_shocks = len(degradation_events)/2
        
        # Find when the first shock happened (if none, default to total cycles)
        if num_shocks > 0:
            first_shock_cycle = degradation_events['Cycle'].min()
        else:
            first_shock_cycle = total_cycles
            
        feature_list.append({
            'Train_ID': train_id,
            'Total_Cycles': total_cycles,
            'Num_Shocks': num_shocks,
            'First_Shock_Cycle': first_shock_cycle
        })
        
    features_df = pd.DataFrame(feature_list)
    
    # 2. Data Scaling
    # GMM is sensitive to scale. Total_Cycles (e.g., 3000) will dominate Num_Shocks (e.g., 5) if not scaled.
    features_to_cluster = ['Total_Cycles', 'Num_Shocks', 'First_Shock_Cycle']
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(features_df[features_to_cluster]) ### NEED TO CHECK IF THIS IS AN APPROPRIATE SCALER
    
    # 3. Apply Gaussian Mixture Model
    # We choose 3 components because the challenge dataset has 3 operating conditions
    gmm = GaussianMixture(n_components=n_clusters, random_state=42, covariance_type='full') ### CHECK THESE CHOICES
    
    # Fit and predict the clusters
    features_df['GMM_Cluster'] = gmm.fit_predict(X_scaled)
    
    # Convert cluster integers to strings so Plotly treats them as discrete categories
    features_df['GMM_Cluster'] = 'Cluster ' + features_df['GMM_Cluster'].astype(str)
    
    return features_df

def find_optimal_gmm_clusters(features_df, max_clusters=10):
    """
    Tests GMM with different numbers of clusters and plots the AIC/BIC scores
    to help you find the optimal number of groups.
    """
    # 1. Scale the data (just like before)
    features_to_cluster = ['Total_Cycles', 'Num_Shocks', 'First_Shock_Cycle']
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(features_df[features_to_cluster])
    
    # Lists to store the scores
    n_components_range = range(1, max_clusters + 1)
    bic_scores = []
    
    # 2. Train a new GMM for every number of clusters and record the scores
    for n in n_components_range:
        gmm = GaussianMixture(n_components=n, random_state=42, covariance_type='full')
        gmm.fit(X_scaled)

        bic_scores.append(gmm.bic(X_scaled))
        
    # 3. Plot the BIC and AIC scores using Plotly
    fig = go.Figure()
    
    fig.add_trace(go.Scatter(x=list(n_components_range), y=bic_scores, 
                             mode='lines+markers', name='BIC Score',
                             line=dict(color='blue', width=2)))
                             
    fig.update_layout(
        title='GMM Model Selection (Lower Score is Better)',
        xaxis_title='Number of Clusters',
        yaxis_title='Information Criterion Score',
        xaxis=dict(tickmode='linear', tick0=1, dtick=1) # Force x-axis to show integers
    )
    
    fig.show()

def plot_hybrid_filtering(df, train_id='Train_15'):
    """
    Plots the raw signal, the FFT denoised line, the Rolling Max upper edge, 
    and the final FDI markers to visually validate the hybrid pipeline.
    """
    # Filter for just one train to keep the plot responsive
    df_plot = df[df['Train_ID'] == train_id]
    
    # Extract the FDI event points
    fdi_points = df_plot[df_plot['FDI'] == 1]
    
    fig = go.Figure()

    # 1. Layer 1: The Raw Noisy Signal (Light Blue, semi-transparent)
    fig.add_trace(go.Scatter(
        x=df_plot.index, 
        y=df_plot['POS_FBK'],
        customdata=df_plot['Cycle'], # <-- Pass the Cycle column here
        hovertemplate="Value: %{y:.2f}<br>Cycle: %{customdata}",
        mode='lines',
        name='1. Raw POS_FBK',
        line=dict(color='green', width=2),
        opacity=0.5
    ))

    # 2. Layer 2: The FFT Denoised Signal (Orange)
    fig.add_trace(go.Scatter(
        x=df_plot.index, 
        y=df_plot['FFT_Denoised'],
        mode='lines',
        name='2. FFT_Denoised',
        line=dict(color='orange', width=2)
    ))

    # 3. Layer 3: The Rolling Max Upper Edge (Dark Blue)
    fig.add_trace(go.Scatter(
        x=df_plot.index, 
        y=df_plot['Monotonic_Edge'],#'Rounded_Edge'
        mode='lines',
        name='3. Moonotonic Edge',
        line=dict(color='darkblue', width=2)
    ))

    # 4. Layer 4: The FDI Boundary Markers (Red Dots)
    fig.add_trace(go.Scatter(
        x=fdi_points.index, 
        y=fdi_points['Monotonic_Edge'],#'Rounded_Edge' # Plotting on the clean edge
        mode='markers',
        name='4. Degradation (FDI=1)',
        marker=dict(color='red', size=5, symbol='circle')
    ))

    # Clean up the layout
    fig.update_layout(
        title=f"Hybrid FFT + Plateau Degradation Filtering ({train_id})",
        xaxis_title="Index",
        yaxis_title="Position",
        hovermode="x unified",
        template="plotly_white"
    )
    
    fig.show()

# %% [markdown]
# ### Importing dataset

# %%
import duckdb

trains = ('Train_1', 'Train_2', 'Train_10', 'Train_11', 'Train_20', 
          'Train_21', 'Train_30', 'Train_31', 'Train_40', 'Train_41')

# 1. Added the ORDER BY clause to prevent the multithreading scramble
query = f"""
    SELECT * FROM 'opening_dataset.parquet' 
    WHERE Train_ID IN {trains}
    ORDER BY Train_ID, Cycle
"""

# 2. Execute query and convert to DataFrame
df_opening_all = duckdb.query(query).to_df()

# 3. Reset the pandas index so it counts cleanly from 0 to N
df_opening_all = df_opening_all.reset_index(drop=True)

# Quick verification
print("Trains loaded:", df_opening_all['Train_ID'].unique())

# %%
print(df_opening_all.shape)
df_opening_all.columns

# %%
df_opening_all.head()

# %%
# Creating the FDI
df_opening_all = label_degradation_hybrid_fft(
    df_opening_all, 
    column='POS_FBK', 
    cutoff_ratio=0.001,       # Frequency cutoff
    window=600,               # Size of the rolling window
    threshold=0.99,           # Threshold for the height or each step
    min_stable_cycles=15)     # Amount of cyles in the step to be considered stable 


# df_opening_all = label_degradation_monotonic(
#     df_opening_all, 
#     column='POS_FBK', 
#     max_window=600, # 10-283 (10 is at the base of the band and 283 is around the middle of the band), 650-730 (with the line at the top of the band), 
#     threshold=0.999999, 
#     min_stable_cycles=17
# )

# %%
df_temp = df_opening_all.loc[::]
plot_hybrid_filtering(df_temp, train_id=trains[0])

# %%
stop

# %%
# Calculating the GMM for group classification
df_opening_all_gmm = cluster_trajectories_gmm(df_opening_all, n_clusters=5)

# %%
# 1. Visualize the Clusters in a 3D Scatter Plot
# fig_scatter = px.scatter_3d(
#     df_opening_all_gmm, 
#     x='Total_Cycles', 
#     y='Num_Shocks', 
#     z='First_Shock_Cycle',
#     color='GMM_Cluster',
#     hover_data=['Train_ID'],
#     title='GMM Clustering of Degradation Profiles'
# )
# fig_scatter.show()

# 2. Map the clusters back to the original time-series data to plot the curves
# We merge the new 'GMM_Cluster' column back into the main dataset
df_opening_all = df_opening_all.merge(df_opening_all_gmm[['Train_ID', 'GMM_Cluster']], on='Train_ID')

fig_lines = px.scatter(
    df_opening_all[::200], 
    x='Cycle', 
    y='POS_FBK', 
    color='GMM_Cluster',
    #line_group='Train_ID', # Ensures each train gets its own line, but colored by cluster
    title='Degradation Trajectories Colored by GMM Cluster'
)
fig_lines.show()
